# %% [markdown]
# # 调用线上的大模型
#
# ## 1. 调用具体模型厂商的API
#
# ### 1.1 调用DeepSeek官网的DeepSeek模型
#
# 调用大模型涉及到三个特别重要的参数：
# base_url、model_name、api_key
#
# 举例1:将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    api_base=OPENAI_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[1], line 20
#      16     api_base=OPENAI_BASE_URL,
#      17 )
#      18
#      19 # 3、模型的调用
# ---> 20 response= llm_deepseek.invoke("请用一句话介绍你自己")
#      21 print(response)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_deepseek/chat_models.py:356, in ChatDeepSeek._generate(self, messages, stop, run_manager, **kwargs)
#     348 def _generate(
#     349     self,
#     350     messages: list[BaseMessage],
#    (...)    353     **kwargs: Any,
#     354 ) -> ChatResult:
#     355     try:
# --> 356         return super()._generate(
#     357             messages,
#     358             stop=stop,
#     359             run_manager=run_manager,
#     360             **kwargs,
#     361         )
#     362     except JSONDecodeError as e:
#     363         msg = (
#     364             "DeepSeek API returned an invalid response. "
#     365             "Please check the API status and try again."
#     366         )
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1492, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1490     _handle_openai_bad_request(e)
#    1491 except openai.APIError as e:
# -> 1492     _handle_openai_api_error(e)
#    1493 except Exception as e:
#    1494     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1487, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1480         return _construct_lc_result_from_responses_api(
#    1481             response,
#    1482             schema=original_schema_obj,
#    1483             metadata=generation_info,
#    1484             output_version=self.output_version,
#    1485         )
#    1486     else:
# -> 1487         raw_response = self.client.with_raw_response.create(**payload)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Authentication Fails, Your api key: ****59f7 is invalid', 'type': 'authentication_error', 'param': None, 'code': 'invalid_request_error'}}
# Failed to multipart ingest runs: langsmith.utils.LangSmithError: Failed to POST https://api.smith.LangChain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %% [markdown]
# 举例2：是对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDopeneepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model=OPENAI_MODE,
    # api_key=OPENAI_API_KEY,
    # api_base=OPENAI_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 举例3：演示一下参数声明在代码中（不推荐）

# %%
from langchain_deepseek import ChatDeepSeek

# 模型的初始化
llm_deepseek = ChatDeepSeek(
    model=OPENAI_MODE,
    api_key="sk-01323021c664464b8a4187d9444259f7",
    api_base="https://api.deepseek.com",
)

# 模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是深度求索创造的AI助手，知识截止到2025年5月，致力于帮助你解决问题！' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户要求用一句话介绍我自己。这是一个非常简单的请求，需要简洁明了地概括我的核心身份和功能。\n\n想到了可以从我的创造者、基本定位、核心能力这几个角度入手。我是由深度求索公司创造的，是一个AI助手，主要功能是回答问题和提供帮助。\n\n准备用“我是深度求索创造的AI助手”作为开头，接着说明“知识截止到2025年5月”，最后强调“致力于帮助你解决问题”。这样一句话就包含了主要信息。'} response_metadata={'token_usage': {'completion_tokens': 122, 'prompt_tokens': 9, 'total_tokens': 131, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 100, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'aef006f3-1e16-47f2-9ead-d995c29b89d4', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3a0b-c4a8-7511-93f6-b764c0d1f5ea-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 122, 'total_tokens': 131, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 100}}

# %% [markdown]
# ### 1.2 通过智谱平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatZhipuAI
import os

from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 2、模型的初始化
llm_zhipu = ChatZhipuAI(
    model=OPENAI_MODE,
    # api_key=OPENAI_API_KEY,
    # api_base=OPENAI_BASE_URL,
)

# 3、模型的调用
response= llm_zhipu.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是Z.ai开发的智能助手，随时为您提供信息和帮助。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 205, 'completion_tokens_details': {'reasoning_tokens': 191}, 'prompt_tokens': 10, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 215}, 'model_name': 'glm-5.1', 'finish_reason': 'stop'} id='lc_run--019e3a85-9629-7773-9aa2-33bc3f5fd58c-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ### 1.3 通过阿里云百炼平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

# 2、模型的初始化
llm_tongyi = ChatTongyi(
    model=OPENAI_MODE,
    # api_key=DASHSCOPE_API_KEY,
)

# 3、模型的调用
response= llm_tongyi.invoke("请用一句话介绍你自己")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 16
#      12     # api_key=DASHSCOPE_API_KEY,
#      13 )
#      14
#      15 # 3、模型的调用
# ---> 16 response= llm_tongyi.invoke("请用一句话介绍你自己")
#      17 print(response)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_community/chat_models/tongyi.py:669, in ChatTongyi._generate(self, messages, stop, run_manager, **kwargs)
#     665 else:
#     666     params: Dict[str, Any] = self._invocation_params(
#     667         messages=messages, stop=stop, **kwargs
#     668     )
# --> 669     resp = self.completion_with_retry(**params)
#     670     generations.append(
#     671         ChatGeneration(**self._chat_generation_from_qwen_resp(resp))
#     672     )
#     673 return ChatResult(
#     674     generations=generations,
#     675     llm_output={
#     676         "model_name": self.model_name,
#     677     },
#     678 )
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_community/chat_models/tongyi.py:540, in ChatTongyi.completion_with_retry(self, **kwargs)
#     537     resp = self.client.call(**_kwargs)
#     538     return check_response(resp)
# --> 540 return _completion_with_retry(**kwargs)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/tenacity/__init__.py:331, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     329 copy = self.copy()
#     330 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331 return copy(f, *args, **kw)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_community/chat_models/tongyi.py:538, in ChatTongyi.completion_with_retry.<locals>._completion_with_retry(**_kwargs)
#     535 @retry_decorator
#     536 def _completion_with_retry(**_kwargs: Any) -> Any:
#     537     resp = self.client.call(**_kwargs)
# --> 538     return check_response(resp)
#
# File /opt/anaconda3/envs/langchaintest/lib/python3.14/site-packages/langchain_community/llms/tongyi.py:61, in check_response(resp)
#      59     return resp
#      60 elif resp["status_code"] in [400, 401]:
# ---> 61     raise ValueError(
#      62         f"request_id: {resp['request_id']} \n "
#      63         f"status_code: {resp['status_code']} \n "
#      64         f"code: {resp['code']} \n message: {resp['message']}"
#      65     )
#      66 else:
#      67     raise HTTPError(
#      68         f"HTTP error occurred: status_code: {resp['status_code']} \n "
#      69         f"code: {resp['code']} \n message: {resp['message']}",
#      70         response=resp,
#      71     )
#
# ValueError: request_id: 590543b3-f332-988e-8cd7-a72af655a0df
#  status_code: 401
#  code: InvalidApiKey
#  message: Invalid API-key provided.

# %% [markdown]
# ## 2. 兼容的写法
#
# 使用ChatOpenAI
#
# 举例1：调用deepseek官网提供的大模型

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
from rich import print as rprint

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = ChatOpenAI(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

rprint(model.invoke("1 + 1 = ？"))
# Out:
# AIMessage(
#     content='1 + 1 = 2',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 49,
#             'prompt_tokens': 11,
#             'total_tokens': 60,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 42,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#         },
#         'model_provider': 'openai',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': None,
#         'id': '021782607738090352115125431e5549369d4d527ff786e385dae',
#         'service_tier': 'default',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f0bb3-73c7-7d43-9b97-0a1cb73d5344-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 11,
#         'output_tokens': 49,
#         'total_tokens': 60,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 42}
#     }
# )

# %% [markdown]
# 举例2：调用智谱平台的大模型

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = ChatOpenAI(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))

# %% [markdown]
# ## 3. 使用中转平台
#
# ### 3.1 使用OpenRouter
#
# 举例1：调用的国内的大模型。比如Deepseek

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = ChatOpenRouter(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='你好！我是DeepSeek，由深度求索公司创造的AI助手，专长是处理文本、阅读链接和文件（支持图像、PDF、Word、Excel等），拥有100万token的超长上下文，完全免费使用，知识截止于2025年5月，希望用热情、细腻的方式帮你解答各种问题！有什么我可以帮你的吗？😊' additional_kwargs={'reasoning_content': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，需要简洁明了地概括我的核心身份和功能。我是DeepSeek，由深度求索公司创造，主要定位是文本处理的AI助手，核心特点包括免费、长上下文、文件处理能力和联网搜索。也需要提及我的知识截止时间，以及我热情细腻的风格。最后用一句友好的话收尾，让用户知道可以随时提问。', 'reasoning_details': [{'type': 'reasoning.text', 'text': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，需要简洁明了地概括我的核心身份和功能。我是DeepSeek，由深度求索公司创造，主要定位是文本处理的AI助手，核心特点包括免费、长上下文、文件处理能力和联网搜索。也需要提及我的知识截止时间，以及我热情细腻的风格。最后用一句友好的话收尾，让用户知道可以随时提问。', 'format': 'unknown', 'index': 0.0}]} response_metadata={'model_name': 'deepseek/deepseek-v4-flash-20260423', 'id': 'gen-1779170997-jbsr7FnqKdvEbOhc8H1p', 'created': 1779170997, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'} id='lc_run--019e3eda-ebd7-71e2-a782-3cb0484d7743-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 166, 'total_tokens': 174, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 87}}

# %% [markdown]
# 举例2：调用国外的大模型。比如gpt

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    # api_key=OPENAI_API_KEY,
    # base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是一个智能助手，旨在提供信息、解决问题和帮助你完成各种任务。' additional_kwargs={} response_metadata={'model_name': 'openai/gpt-4o-mini', 'id': 'gen-1779164104-K5SzOU56y01w5vcDjuKz', 'created': 1779164104, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'system_fingerprint': 'fp_eb37e061ec'} id='lc_run--019e3e71-c067-7fe3-a23f-3f2d9bae1da0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 20, 'total_tokens': 33, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}

# %% [markdown]
# ### 3.2 使用CloseAI平台
#
# 举例1：调用国内的大模型。比如deepseek

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = ChatOpenAI(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# 举例2：调用国外的大模型。比如：gpt

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = ChatOpenAI(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))

# %% [markdown]
# ## 4. 使用LangChain1.x的统一方式
#
# 使用 init_chat_model()
#
# 举例1：调用DeepSeek官网的DeepSeek模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv
from rich import print

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = init_chat_model(
    # model=OPENAI_MODE,
    # model_provider="deepseek",
    # 或者
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# AIMessage(
#     content='我是由字节跳动开发训练的人工智能豆包，具备知识答疑、创意生成、聊天互动等多种能力，能为你提供各类实用帮
# 助。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 216,
#             'prompt_tokens': 54,
#             'total_tokens': 270,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 183,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}
#         },
#         'model_provider': 'openai',
#         'model_name': 'doubao-seed-2.0-pro',
#         'system_fingerprint': None,
#         'id': '02178260853726941b543c0bdbbf2d644f33f27e04d485eed356f',
#         'service_tier': 'default',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f0bbf-a5bb-7421-88d0-1e6065f44cd9-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 54,
#         'output_tokens': 216,
#         'total_tokens': 270,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 183}
#     }
# )

# %% [markdown]
# 举例2：调用CloseAI平台的大模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = init_chat_model(
    model="openai:deepseek-v4-flash",
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是DeepSeek，一个由深度求索公司创造的AI助手，致力于为你提供智能、免费且支持长上下文和文件处理的对话服务。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 143, 'prompt_tokens': 8, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 110, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': None, 'id': 'chatcmpl-ac122291-16fe-985c-ae96-86daa00179ed', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3f2f-6746-77e3-970a-65974325d4e2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 143, 'total_tokens': 151, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 110}}

# %% [markdown]
# 举例3：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_BASE_URL = os.getenv("OPENAI_BASE_URL")

OPENAI_MODE = os.getenv("OPENAI_MODE")

# 获取大模型
model = init_chat_model(
    model=OPENAI_MODE,
    api_key=OPENAI_API_KEY,
    base_url=OPENAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是一个由 OpenAI 训练的 AI 助手，能帮你回答问题、写作、翻译、总结和处理各种文本任务。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 12, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 33, 'engine_ttlt_ms': 209, 'pre_inference_ms': 90, 'service_tbt_ms': 5, 'service_ttft_ms': 178, 'service_ttlt_ms': 353, 'total_duration_ms': 268, 'user_visible_ttft_ms': 89}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dh9OSprhyTQTVVXI3NYg3F42q811m', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3f30-2fa0-7c61-a234-fbdd9eeecb88-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 36, 'total_tokens': 48, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## 5. 小结
#
# DeepSeek官网的DeepSeek模型：ChatDeepSeek() 、 ChatOpenAI() 、 init_chat_model()
#
# 阿里云百炼平台的DeepSeek模型：ChatTongyi() 、ChatOpenAI() 、 init_chat_model()
#
# OpenRouter平台的DeepSeek模型：ChatOpenRouter() 、 ChatOpenAI()、init_chat_model()
#
# CloseAI平台的DeepSeek模型：ChatOpenAI()、init_chat_model()
